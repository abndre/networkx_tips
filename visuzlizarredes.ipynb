 (10154, 6318, {'date': datetime.date(2013, 5, 27)}),
 (10154, 2055, {'date': datetime.date(2013, 9, 19)}),
 (5035, 556, {'date': datetime.date(2012, 5, 19)}),
 (1971, 11808, {'date': datetime.date(2007, 4, 26)}),
 (1971, 11819, {'date': datetime.date(2008, 8, 12)}),
 (1971, 22164, {'date': datetime.date(2010, 2, 4)}),
 (7102, 7110, {'date': datetime.date(2011, 9, 11)}),
 (13257, 13274, {'date': datetime.date(2007, 12, 13)}),
 (13257, 3283, {'date': datetime.date(2007, 10, 20)}),
 (20430, 20433, {'date': datetime.date(2009, 4, 15)}),
 (12245, 12258, {'date': datetime.date(2007, 10, 27)}),
 (5881, 5881, {'date': datetime.date(2009, 5, 11)}),
 (6620, 11656, {'date': datetime.date(2011, 3, 20)}),
 (6620, 537, {'date': datetime.date(2010, 6, 26)}),
 (6620, 4925, {'date': datetime.date(2013, 5, 25)}),
 (21478, 11281, {'date': datetime.date(2008, 9, 21)}),
 (21478, 1073, {'date': datetime.date(2008, 11, 2)}),
 (23024, 23063, {'date': datetime.date(2011, 5, 5)}),
 (13306, 13311, {'date': datetime.date(2010, 2, 7)})]

datanodes = [(2562, {'category': 'D', 'occupation': 'scientist'}),
 (9219, {'category': 'P', 'occupation': 'celebrity'}),
 (2055, {'category': 'I', 'occupation': 'scientist'}),
 (9227, {'category': 'P', 'occupation': 'celebrity'}),
 (3086, {'category': 'D', 'occupation': 'celebrity'}),
 (15924, {'category': 'I', 'occupation': 'celebrity'}),
 (11281, {'category': 'P', 'occupation': 'politician'}),
 (23063, {'category': 'I', 'occupation': 'politician'}),
 (21017, {'category': 'D', 'occupation': 'scientist'}),
 (21019, {'category': 'I', 'occupation': 'scientist'}),
 (4636, {'category': 'I', 'occupation': 'politician'}),
 (22046, {'category': 'D', 'occupation': 'politician'}),
 (11808, {'category': 'D', 'occupation': 'celebrity'}),
 (9765, {'category': 'P', 'occupation': 'celebrity'}),
 (2598, {'category': 'P', 'occupation': 'celebrity'}),
 (7719, {'category': 'P', 'occupation': 'politician'}),
 (11819, {'category': 'I', 'occupation': 'scientist'}),
 (556, {'category': 'I', 'occupation': 'celebrity'}),
 (7858, {'category': 'I', 'occupation': 'scientist'}),
 (4654, {'category': 'I', 'occupation': 'politician'}),
 (8239, {'category': 'I', 'occupation': 'celebrity'}),
 (1073, {'category': 'D', 'occupation': 'politician'}),
 (12340, {'category': 'D', 'occupation': 'scientist'}),
 (14390, {'category': 'D', 'occupation': 'scientist'}),
 (15929, {'category': 'D', 'occupation': 'politician'}),
 (12346, {'category': 'I', 'occupation': 'scientist'}),
 (1599, {'category': 'D', 'occupation': 'celebrity'}),
 (11328, {'category': 'P', 'occupation': 'celebrity'}),
 (7746, {'category': 'D', 'occupation': 'celebrity'}),
 (19011, {'category': 'I', 'occupation': 'scientist'}),
 (15430, {'category': 'P', 'occupation': 'politician'}),
 (16455, {'category': 'D', 'occupation': 'politician'}),
 (1097, {'category': 'I', 'occupation': 'politician'}),
 (75, {'category': 'P', 'occupation': 'celebrity'}),
 (76, {'category': 'D', 'occupation': 'politician'}),
 (1613, {'category': 'P', 'occupation': 'scientist'}),
 (14414, {'category': 'D', 'occupation': 'politician'}),
 (15439, {'category': 'D', 'occupation': 'politician'}),
 (7764, {'category': 'P', 'occupation': 'scientist'}),
 (2646, {'category': 'I', 'occupation': 'scientist'}),
 (3159, {'category': 'D', 'occupation': 'scientist'}),
 (14425, {'category': 'I', 'occupation': 'celebrity'}),
 (2650, {'category': 'D', 'occupation': 'celebrity'}),
 (17500, {'category': 'D', 'occupation': 'celebrity'}),
 (2654, {'category': 'P', 'occupation': 'politician'}),
 (6243, {'category': 'I', 'occupation': 'celebrity'}),
 (1773, {'category': 'D', 'occupation': 'scientist'}),
 (5229, {'category': 'P', 'occupation': 'celebrity'}),
 (13672, {'category': 'D', 'occupation': 'politician'}),
 (2677, {'category': 'I', 'occupation': 'politician'}),
 (5908, {'category': 'P', 'occupation': 'politician'}),
 (20602, {'category': 'D', 'occupation': 'scientist'}),
 (14462, {'category': 'I', 'occupation': 'politician'}),
 (10368, {'category': 'D', 'occupation': 'scientist'}),
 (10373, {'category': 'P', 'occupation': 'scientist'}),
 (8948, {'category': 'I', 'occupation': 'celebrity'}),
 (1731, {'category': 'P', 'occupation': 'politician'}),
 (22164, {'category': 'I', 'occupation': 'politician'}),
 (414, {'category': 'I', 'occupation': 'scientist'}),
 (537, {'category': 'D', 'occupation': 'celebrity'}),
 (1179, {'category': 'P', 'occupation': 'celebrity'}),
 (14494, {'category': 'D', 'occupation': 'politician'}),
 (14021, {'category': 'D', 'occupation': 'politician'}),
 (1696, {'category': 'I', 'occupation': 'celebrity'}),
 (21153, {'category': 'P', 'occupation': 'celebrity'}),
 (22184, {'category': 'I', 'occupation': 'scientist'}),
 (6318, {'category': 'I', 'occupation': 'celebrity'}),
 (5810, {'category': 'P', 'occupation': 'celebrity'}),
 (18845, {'category': 'I', 'occupation': 'politician'}),
 (4284, {'category': 'P', 'occupation': 'scientist'}),
 (11966, {'category': 'P', 'occupation': 'scientist'}),
 (3189, {'category': 'P', 'occupation': 'celebrity'}),
 (192, {'category': 'P', 'occupation': 'politician'}),
 (2753, {'category': 'D', 'occupation': 'celebrity'}),
 (14019, {'category': 'I', 'occupation': 'celebrity'}),
 (2934, {'category': 'P', 'occupation': 'celebrity'}),
 (4811, {'category': 'I', 'occupation': 'politician'}),
 (7886, {'category': 'P', 'occupation': 'scientist'}),
 (6353, {'category': 'D', 'occupation': 'scientist'}),
 (3283, {'category': 'P', 'occupation': 'scientist'}),
 (7383, {'category': 'D', 'occupation': 'politician'}),
 (3289, {'category': 'D', 'occupation': 'celebrity'}),
 (22746, {'category': 'D', 'occupation': 'scientist'}),
 (2268, {'category': 'D', 'occupation': 'politician'}),
 (4317, {'category': 'I', 'occupation': 'celebrity'}),
 (23024, {'category': 'I', 'occupation': 'scientist'}),
 (2275, {'category': 'P', 'occupation': 'celebrity'}),
 (2292, {'category': 'I', 'occupation': 'scientist'}),
 (20756, {'category': 'I', 'occupation': 'scientist'}),
 (20433, {'category': 'P', 'occupation': 'celebrity'}),
 (5864, {'category': 'I', 'occupation': 'scientist'}),
 (7401, {'category': 'D', 'occupation': 'scientist'}),
 (22250, {'category': 'I', 'occupation': 'politician'}),
 (13036, {'category': 'P', 'occupation': 'politician'}),
 (6893, {'category': 'D', 'occupation': 'politician'}),
 (18163, {'category': 'I', 'occupation': 'politician'}),
 (22772, {'category': 'D', 'occupation': 'scientist'}),
 (3317, {'category': 'I', 'occupation': 'scientist'}),
 (1747, {'category': 'I', 'occupation': 'politician'}),
 (1273, {'category': 'I', 'occupation': 'scientist'}),
 (19706, {'category': 'D', 'occupation': 'politician'}),
 (2299, {'category': 'D', 'occupation': 'scientist'}),
 (19711, {'category': 'D', 'occupation': 'politician'}),
 (22790, {'category': 'P', 'occupation': 'scientist'}),
 (4481, {'category': 'D', 'occupation': 'scientist'}),
 (8968, {'category': 'P', 'occupation': 'celebrity'}),
 (1299, {'category': 'I', 'occupation': 'politician'}),
 (10004, {'category': 'D', 'occupation': 'politician'}),
 (11822, {'category': 'P', 'occupation': 'scientist'}),
 (2327, {'category': 'D', 'occupation': 'politician'}),
 (792, {'category': 'I', 'occupation': 'scientist'}),
 (7727, {'category': 'D', 'occupation': 'politician'}),
 (1824, {'category': 'D', 'occupation': 'scientist'}),
 (14113, {'category': 'I', 'occupation': 'scientist'}),
 (803, {'category': 'P', 'occupation': 'scientist'}),
 (8996, {'category': 'I', 'occupation': 'politician'}),
 (13616, {'category': 'I', 'occupation': 'scientist'}),
 (21813, {'category': 'I', 'occupation': 'politician'}),
 (2871, {'category': 'I', 'occupation': 'scientist'}),
 (18745, {'category': 'I', 'occupation': 'politician'}),
 (3898, {'category': 'I', 'occupation': 'celebrity'}),
 (15164, {'category': 'I', 'occupation': 'scientist'}),
 (4925, {'category': 'I', 'occupation': 'celebrity'}),
 (20799, {'category': 'D', 'occupation': 'celebrity'}),
 (3904, {'category': 'D', 'occupation': 'politician'}),
 (15681, {'category': 'D', 'occupation': 'politician'}),
 (22850, {'category': 'I', 'occupation': 'celebrity'}),
 (5952, {'category': 'P', 'occupation': 'celebrity'}),
 (3920, {'category': 'I', 'occupation': 'scientist'}),
 (15699, {'category': 'I', 'occupation': 'celebrity'}),
 (6484, {'category': 'D', 'occupation': 'politician'}),
 (825, {'category': 'P', 'occupation': 'celebrity'}),
 (4968, {'category': 'I', 'occupation': 'politician'}),
 (16786, {'category': 'D', 'occupation': 'politician'}),
 (13167, {'category': 'D', 'occupation': 'scientist'}),
 (16752, {'category': 'P', 'occupation': 'scientist'}),
 (10101, {'category': 'D', 'occupation': 'politician'}),
 (4470, {'category': 'P', 'occupation': 'scientist'}),
 (20855, {'category': 'I', 'occupation': 'celebrity'}),
 (4986, {'category': 'I', 'occupation': 'scientist'}),
 (12160, {'category': 'D', 'occupation': 'scientist'}),
 (6464, {'category': 'D', 'occupation': 'celebrity'}),
 (12679, {'category': 'P', 'occupation': 'scientist'}),
 (11656, {'category': 'I', 'occupation': 'politician'}),
 (12687, {'category': 'P', 'occupation': 'celebrity'}),
 (13200, {'category': 'D', 'occupation': 'scientist'}),
 (401, {'category': 'P', 'occupation': 'politician'}),
 (8594, {'category': 'P', 'occupation': 'politician'}),
 (9110, {'category': 'P', 'occupation': 'scientist'}),
 (10138, {'category': 'P', 'occupation': 'celebrity'}),
 (9114, {'category': 'P', 'occupation': 'celebrity'}),
 (18846, {'category': 'P', 'occupation': 'celebrity'}),
 (18848, {'category': 'D', 'occupation': 'scientist'}),
 (9633, {'category': 'P', 'occupation': 'scientist'}),
 (15784, {'category': 'D', 'occupation': 'politician'}),
 (10154, {'category': 'I', 'occupation': 'scientist'}),
 (5035, {'category': 'I', 'occupation': 'celebrity'}),
 (1965, {'category': 'I', 'occupation': 'politician'}),
 (12701, {'category': 'D', 'occupation': 'scientist'}),
 (1971, {'category': 'P', 'occupation': 'celebrity'}),
 (3230, {'category': 'I', 'occupation': 'scientist'}),
 (7606, {'category': 'I', 'occupation': 'scientist'}),
 (2999, {'category': 'P', 'occupation': 'politician'}),
 (10168, {'category': 'I', 'occupation': 'scientist'}),
 (18164, {'category': 'I', 'occupation': 'celebrity'}),
 (9660, {'category': 'I', 'occupation': 'celebrity'}),
 (7102, {'category': 'P', 'occupation': 'scientist'}),
 (4546, {'category': 'D', 'occupation': 'politician'}),
 (7110, {'category': 'I', 'occupation': 'scientist'}),
 (13257, {'category': 'P', 'occupation': 'celebrity'}),
 (20430, {'category': 'P', 'occupation': 'celebrity'}),
 (9679, {'category': 'I', 'occupation': 'politician'}),
 (19921, {'category': 'P', 'occupation': 'politician'}),
 (12245, {'category': 'P', 'occupation': 'scientist'}),
 (982, {'category': 'D', 'occupation': 'politician'}),
 (5881, {'category': 'P', 'occupation': 'politician'}),
 (13274, {'category': 'P', 'occupation': 'celebrity'}),
 (6620, {'category': 'P', 'occupation': 'scientist'}),
 (5968, {'category': 'I', 'occupation': 'celebrity'}),
 (12258, {'category': 'D', 'occupation': 'scientist'}),
 (21478, {'category': 'D', 'occupation': 'politician'}),
 (13816, {'category': 'D', 'occupation': 'politician'}),
 (3119, {'category': 'P', 'occupation': 'politician'}),
 (13808, {'category': 'P', 'occupation': 'celebrity'}),
 (10225, {'category': 'P', 'occupation': 'celebrity'}),
 (2040, {'category': 'P', 'occupation': 'celebrity'}),
 (16468, {'category': 'D', 'occupation': 'politician'}),
 (13306, {'category': 'I', 'occupation': 'scientist'}),
 (13311, {'category': 'I', 'occupation': 'politician'})]

# %%
T=nx.DiGraph()
T.add_nodes_from(datanodes)
T.add_edges_from(dataedges)

nx.draw_networkx(T)
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/networkx/drawing/nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#
# /usr/local/lib/python3.5/dist-packages/networkx/drawing/nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   edge_colors = (colorConverter.to_rgba(edge_color, alpha), )
# /usr/local/lib/python3.5/dist-packages/networkx/drawing/nx_pylab.py:724: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   label = str(label)  # this will cause "1" and 1 to be labeled the same

# %%
m = nv.MatrixPlot(T)

# Draw m to the screen
m.draw()

# Display the plot
plt.show()

# Convert T to a matrix format: A
A = nx.to_numpy_matrix(T)

# Convert A back to the NetworkX form as a directed graph: T_conv
T_conv = nx.from_numpy_matrix(A, create_using=nx.DiGraph())

# Check that the `category` metadata field is lost from each node
for n, d in T_conv.nodes(data=True):
    assert 'category' not in d.keys()

# %%
from nxviz import CircosPlot

# Create the CircosPlot object: c
c = CircosPlot(T)

# Draw c to the screen
c.draw()

# Display the plot
plt.show()

# %%
from nxviz import ArcPlot

# Create the un-customized ArcPlot object: a
a = ArcPlot(T)

# Draw a to the screen
a.draw()

# Display the plot
plt.show()

# %%
# Create the customized ArcPlot object: a2
a2 = ArcPlot(T,node_order='category',node_color='category')

# Draw a2 to the screen
a2.draw()

# Display the plot
plt.show()
